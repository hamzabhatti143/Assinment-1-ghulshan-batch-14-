# %%
import pandas as pd

# %%
data = pd.read_csv("Real estate.csv")

data.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
data.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
x = data[['X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']]
y = data[['Y house price of unit area']]

# %%
print(x.shape)
print(y.shape)
# Out:
# (414, 5)
# (414, 1)

# %%
print(x.head())
print(y.head())
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.20, random_state=32)

# %%
x_train.shape
# Out:
# (331, 5)

# %%
x_test.shape
# Out:
# (83, 5)

# %%
y_train.shape, y_test.shape
# Out:
# ((331, 1), (83, 1))

# %%
from sklearn.linear_model import LinearRegression

unit_price_predictor = LinearRegression()

# %%
unit_price_predictor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
unit_price_predictor.coef_
# Out:
# array([[-2.69586467e-01, -4.12788028e-03,  1.20941290e+00,
#          2.31982585e+02, -1.74223516e+01]])

# %%
unit_price_predictor.intercept_
# Out:
# array([-3632.85337239])

# %%
y_pred_train = unit_price_predictor.predict(x_train)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
import math
math.sqrt(mean_squared_error(y_train, y_pred_train))
# Out:
# 8.96304065869006

# %%
r2_score(y_train, y_pred_train)
# Out:
# 0.5631080292895736

# %%
mean_absolute_error(y_train, y_pred_train)
# Out:
# 6.096824214043061

# %%
y_pred_test = performance_predictor.predict(x_test)

# %%
import math
math.sqrt(mean_squared_error(y_test, y_pred_test))
# Out:
# 8.671263543258254

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.5919770506959802

# %%
mean_absolute_error(y_test, y_pred_test)
# Out:
# 6.3341817733140156

# %%
print(x.head())
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245

# %%
def unit_price_pred(X2_house_age, X3_distance_to_MRT, X4_convenience_stores, X5_latitude, X6_longitude):
    user_input = pd.DataFrame({
        'X2 house age': [X2_house_age],
        'X3 distance to the nearest MRT station': [X3_distance_to_MRT],
        'X4 number of convenience stores': [X4_convenience_stores],
        'X5 latitude': [X5_latitude],
        'X6 longitude': [X6_longitude]
    })
    return unit_price_predictor.predict(user_input)

# %%
X2_house_age = float(input("Enter House Age: "))
X3_distance_to_MRT = float(input("Enter MRT distance: "))
X4_convenience_stores = float(input("Enter Convenience Stores : "))
X5_latitude = float(input("Enter Latitude : "))
X6_longitude = float(input("Enter Longtitude: "))

prediction = unit_price_pred(X2_house_age, X3_distance_to_MRT, X4_convenience_stores, X5_latitude, X6_longitude)

print("\n========== Insurance Prediction ==========")
print(f"House Age              : {X2_house_age}")
print(f"MRT Distance              : {X3_distance_to_MRT}")
print(f"Convenience Stores              : {X4_convenience_stores}")
print(f"Latitude         : {X5_latitude}")
print(f"Longtitude           : {X6_longitude}")
print("------------------------------------------")
print(f"Predicted Charges : ${prediction}")
print("==========================================")
# Out:
# Enter House Age:  32.5
# Enter MRT distance:  019221
# Enter Convenience Stores :  20
# Enter Latitude :  24.98034
# Enter Longtitude:  121.54245
# ========== Insurance Prediction ==========
# House Age              : 32.5
# MRT Distance              : 19221.0
# Convenience Stores              : 20.0
# Latitude         : 24.98034
# Longtitude           : 121.54245
# ------------------------------------------
# Predicted Charges : $[[-19.32010807]]
# ...
